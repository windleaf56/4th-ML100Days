# %% [markdown]
# ## Work
# 1. 請嘗試將 preproc_x 替換成以每筆資料的 min/max 進行標準化至 -1 ~ 1 間，再進行訓練
# 2. 請嘗試將 mlp 疊更深 (e.g 5~10 層)，進行訓練後觀察 learning curve 的走勢
# 3. (optional) 請改用 GPU 進行訓練 (如果你有 GPU 的話)，比較使用 CPU 與 GPU 的訓練速度

# %%
## 
"""
Your code here (optional)
確認硬體資源
"""

# %%
import os
import keras

# 請嘗試設定 GPU：os.environ
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
import os
import keras
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
"""
Your code here
"""
def preproc_x(x, flatten=True):
    x = ((x/255)-0.5)*2
    if flatten:
        x = x.reshape((len(x), -1))
    return x
    
def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
"""Code Here
建立你的神經網路
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128, 64, 32]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
            
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
## 超參數設定
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 256

# %%
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

# %%
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.9675 - accuracy: 0.2906 - val_loss: 1.8085 - val_accuracy: 0.3508
# Epoch 2/100
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.7338 - accuracy: 0.3783 - val_loss: 1.6709 - val_accuracy: 0.4013
# Epoch 3/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.6311 - accuracy: 0.4169 - val_loss: 1.6614 - val_accuracy: 0.4040
# Epoch 4/100
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.5659 - accuracy: 0.4437 - val_loss: 1.5363 - val_accuracy: 0.4502
# Epoch 5/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.5148 - accuracy: 0.4622 - val_loss: 1.4901 - val_accuracy: 0.4686
# Epoch 6/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.4775 - accuracy: 0.4733 - val_loss: 1.4866 - val_accuracy: 0.4703
# Epoch 7/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 1.4393 - accuracy: 0.4856 - val_loss: 1.4511 - val_accuracy: 0.4833
# Epoch 8/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.4175 - accuracy: 0.4951 - val_loss: 1.5353 - val_accuracy: 0.4642
# Epoch 9/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.3853 - accuracy: 0.5069 - val_loss: 1.4114 - val_accuracy: 0.4968
# Epoch 10/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.3590 - accuracy: 0.5155 - val_loss: 1.4251 - val_accuracy: 0.4935
# Epoch 11/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.3301 - accuracy: 0.5265 - val_loss: 1.4177 - val_accuracy: 0.5051
# Epoch 12/100
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.3097 - accuracy: 0.5328 - val_loss: 1.3884 - val_accuracy: 0.5106
# Epoch 13/100
# 50000/50000 [==============================] - 3s 69us/step - loss: 1.2866 - accuracy: 0.5443 - val_loss: 1.4214 - val_accuracy: 0.4931
# Epoch 14/100
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.2509 - accuracy: 0.5551 - val_loss: 1.3734 - val_accuracy: 0.5163
# Epoch 15/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.2381 - accuracy: 0.5592 - val_loss: 1.4039 - val_accuracy: 0.5062
# Epoch 16/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.2105 - accuracy: 0.5693 - val_loss: 1.3897 - val_accuracy: 0.5154
# Epoch 17/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.2004 - accuracy: 0.5731 - val_loss: 1.3684 - val_accuracy: 0.5113
# Epoch 18/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.1715 - accuracy: 0.5811 - val_loss: 1.3793 - val_accuracy: 0.5147
# Epoch 19/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.1481 - accuracy: 0.5899 - val_loss: 1.3824 - val_accuracy: 0.5160
# Epoch 20/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.1323 - accuracy: 0.5961 - val_loss: 1.3684 - val_accuracy: 0.5130
# Epoch 21/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.1004 - accuracy: 0.6087 - val_loss: 1.3713 - val_accuracy: 0.5247
# Epoch 22/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.0880 - accuracy: 0.6141 - val_loss: 1.3770 - val_accuracy: 0.5217
# Epoch 23/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0657 - accuracy: 0.6206 - val_loss: 1.3712 - val_accuracy: 0.5267
# Epoch 24/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 1.0536 - accuracy: 0.6237 - val_loss: 1.4056 - val_accuracy: 0.5165
# Epoch 25/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 1.0293 - accuracy: 0.6351 - val_loss: 1.3843 - val_accuracy: 0.5251
# Epoch 26/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.0084 - accuracy: 0.6412 - val_loss: 1.3792 - val_accuracy: 0.5368
# Epoch 27/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.9883 - accuracy: 0.6476 - val_loss: 1.4040 - val_accuracy: 0.5233
# Epoch 28/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.9807 - accuracy: 0.6475 - val_loss: 1.4278 - val_accuracy: 0.5221
# Epoch 29/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.9675 - accuracy: 0.6564 - val_loss: 1.4136 - val_accuracy: 0.5293
# Epoch 30/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.9359 - accuracy: 0.6661 - val_loss: 1.4556 - val_accuracy: 0.5209
# Epoch 31/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.9208 - accuracy: 0.6700 - val_loss: 1.4760 - val_accuracy: 0.5155
# Epoch 32/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.9042 - accuracy: 0.6789 - val_loss: 1.5235 - val_accuracy: 0.5191
# Epoch 33/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.8827 - accuracy: 0.6834 - val_loss: 1.4776 - val_accuracy: 0.5224
# Epoch 34/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.8673 - accuracy: 0.6886 - val_loss: 1.4679 - val_accuracy: 0.5340
# Epoch 35/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.8502 - accuracy: 0.6958 - val_loss: 1.5125 - val_accuracy: 0.5176
# Epoch 36/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.8316 - accuracy: 0.7043 - val_loss: 1.5276 - val_accuracy: 0.5244
# Epoch 37/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.8223 - accuracy: 0.7071 - val_loss: 1.5023 - val_accuracy: 0.5277
# Epoch 38/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.7988 - accuracy: 0.7130 - val_loss: 1.5947 - val_accuracy: 0.5191
# Epoch 39/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.7871 - accuracy: 0.7180 - val_loss: 1.6151 - val_accuracy: 0.5160
# Epoch 40/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.7780 - accuracy: 0.7217 - val_loss: 1.5280 - val_accuracy: 0.5347
# Epoch 41/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.7528 - accuracy: 0.7308 - val_loss: 1.5680 - val_accuracy: 0.5316
# Epoch 42/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.7485 - accuracy: 0.7335 - val_loss: 1.5973 - val_accuracy: 0.5253
# Epoch 43/100
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.7358 - accuracy: 0.7376 - val_loss: 1.6618 - val_accuracy: 0.5282
# Epoch 44/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.7080 - accuracy: 0.7469 - val_loss: 1.6644 - val_accuracy: 0.5171
# Epoch 45/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.6959 - accuracy: 0.7516 - val_loss: 1.6891 - val_accuracy: 0.5167
# Epoch 46/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.6774 - accuracy: 0.7588 - val_loss: 1.7193 - val_accuracy: 0.5141
# Epoch 47/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.6813 - accuracy: 0.7544 - val_loss: 1.7488 - val_accuracy: 0.5092
# Epoch 48/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.6597 - accuracy: 0.7644 - val_loss: 1.8097 - val_accuracy: 0.5145
# Epoch 49/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.6572 - accuracy: 0.7644 - val_loss: 1.7552 - val_accuracy: 0.5184
# Epoch 50/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.6280 - accuracy: 0.7753 - val_loss: 1.8311 - val_accuracy: 0.5156
# Epoch 51/100
# 50000/50000 [==============================] - 4s 70us/step - loss: 0.6305 - accuracy: 0.7752 - val_loss: 1.8009 - val_accuracy: 0.5240
# Epoch 52/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.6012 - accuracy: 0.7851 - val_loss: 1.8701 - val_accuracy: 0.5246
# Epoch 53/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.5898 - accuracy: 0.7901 - val_loss: 1.8689 - val_accuracy: 0.5228
# Epoch 54/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.5896 - accuracy: 0.7887 - val_loss: 1.8994 - val_accuracy: 0.5220
# Epoch 55/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.5631 - accuracy: 0.7998 - val_loss: 1.9326 - val_accuracy: 0.5197
# Epoch 56/100
# 50000/50000 [==============================] - 4s 78us/step - loss: 0.5594 - accuracy: 0.8013 - val_loss: 1.9567 - val_accuracy: 0.5205
# Epoch 57/100
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.5520 - accuracy: 0.8016 - val_loss: 2.0205 - val_accuracy: 0.5113
# Epoch 58/100
# 50000/50000 [==============================] - 3s 60us/step - loss: 0.5335 - accuracy: 0.8113 - val_loss: 2.0009 - val_accuracy: 0.5176
# Epoch 59/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.5312 - accuracy: 0.8103 - val_loss: 1.9921 - val_accuracy: 0.5114
# Epoch 60/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.5262 - accuracy: 0.8111 - val_loss: 2.0631 - val_accuracy: 0.5172
# Epoch 61/100
# 50000/50000 [==============================] - 4s 74us/step - loss: 0.5113 - accuracy: 0.8185 - val_loss: 2.1015 - val_accuracy: 0.5125
# Epoch 62/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.5073 - accuracy: 0.8188 - val_loss: 2.1170 - val_accuracy: 0.5204
# Epoch 63/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.4843 - accuracy: 0.8275 - val_loss: 2.2006 - val_accuracy: 0.5128
# Epoch 64/100
# 50000/50000 [==============================] - 4s 72us/step - loss: 0.4844 - accuracy: 0.8263 - val_loss: 2.1873 - val_accuracy: 0.5139
# Epoch 65/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.4819 - accuracy: 0.8285 - val_loss: 2.2007 - val_accuracy: 0.5123
# Epoch 66/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.4905 - accuracy: 0.8245 - val_loss: 2.2102 - val_accuracy: 0.5129
# Epoch 67/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.4601 - accuracy: 0.8359 - val_loss: 2.2314 - val_accuracy: 0.5111
# Epoch 68/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.4569 - accuracy: 0.8362 - val_loss: 2.3388 - val_accuracy: 0.5094
# Epoch 69/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.4515 - accuracy: 0.8390 - val_loss: 2.3509 - val_accuracy: 0.5058
# Epoch 70/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.4399 - accuracy: 0.8420 - val_loss: 2.4182 - val_accuracy: 0.5111
# Epoch 71/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.4363 - accuracy: 0.8435 - val_loss: 2.4524 - val_accuracy: 0.5002
# Epoch 72/100
# 50000/50000 [==============================] - 3s 68us/step - loss: 0.4068 - accuracy: 0.8539 - val_loss: 2.4837 - val_accuracy: 0.5085
# Epoch 73/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.4109 - accuracy: 0.8531 - val_loss: 2.4813 - val_accuracy: 0.5137
# Epoch 74/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.3940 - accuracy: 0.8598 - val_loss: 2.5654 - val_accuracy: 0.5070
# Epoch 75/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.4264 - accuracy: 0.8469 - val_loss: 2.5062 - val_accuracy: 0.5061
# Epoch 76/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.4087 - accuracy: 0.8539 - val_loss: 2.5937 - val_accuracy: 0.5056
# Epoch 77/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.3884 - accuracy: 0.8605 - val_loss: 2.5714 - val_accuracy: 0.5087
# Epoch 78/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.3903 - accuracy: 0.8599 - val_loss: 2.5528 - val_accuracy: 0.5165
# Epoch 79/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.3721 - accuracy: 0.8666 - val_loss: 2.5999 - val_accuracy: 0.5104
# Epoch 80/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.3775 - accuracy: 0.8631 - val_loss: 2.6675 - val_accuracy: 0.5063
# Epoch 81/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.3726 - accuracy: 0.8686 - val_loss: 2.6791 - val_accuracy: 0.5137
# Epoch 82/100
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.3763 - accuracy: 0.8662 - val_loss: 2.6890 - val_accuracy: 0.5037
# Epoch 83/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.3530 - accuracy: 0.8721 - val_loss: 2.8404 - val_accuracy: 0.4939
# Epoch 84/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.3606 - accuracy: 0.8713 - val_loss: 2.7591 - val_accuracy: 0.5040
# Epoch 85/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.3382 - accuracy: 0.8790 - val_loss: 2.8249 - val_accuracy: 0.5057
# Epoch 86/100
# 50000/50000 [==============================] - 3s 67us/step - loss: 0.3294 - accuracy: 0.8830 - val_loss: 2.9128 - val_accuracy: 0.5009
# Epoch 87/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.3381 - accuracy: 0.8787 - val_loss: 2.8420 - val_accuracy: 0.5097
# Epoch 88/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.3446 - accuracy: 0.8755 - val_loss: 2.9421 - val_accuracy: 0.5084
# Epoch 89/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.3279 - accuracy: 0.8823 - val_loss: 2.9664 - val_accuracy: 0.5043
# Epoch 90/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.3295 - accuracy: 0.8814 - val_loss: 3.0052 - val_accuracy: 0.4988
# Epoch 91/100
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.3212 - accuracy: 0.8861 - val_loss: 3.0068 - val_accuracy: 0.5046
# Epoch 92/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.3145 - accuracy: 0.8880 - val_loss: 2.9573 - val_accuracy: 0.5020
# Epoch 93/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.3007 - accuracy: 0.8930 - val_loss: 3.1551 - val_accuracy: 0.5035
# Epoch 94/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.2932 - accuracy: 0.8965 - val_loss: 3.2198 - val_accuracy: 0.4991
# Epoch 95/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.3306 - accuracy: 0.8810 - val_loss: 3.1961 - val_accuracy: 0.4995
# Epoch 96/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.3131 - accuracy: 0.8860 - val_loss: 3.1860 - val_accuracy: 0.4993
# Epoch 97/100
# 50000/50000 [==============================] - 3s 65us/step - loss: 0.3016 - accuracy: 0.8910 - val_loss: 3.1286 - val_accuracy: 0.5031
# Epoch 98/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.2973 - accuracy: 0.8937 - val_loss: 3.2394 - val_accuracy: 0.5025
# Epoch 99/100
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.2922 - accuracy: 0.8963 - val_loss: 3.4114 - val_accuracy: 0.4963
# Epoch 100/100
# 50000/50000 [==============================] - 3s 62us/step - loss: 0.2938 - accuracy: 0.8937 - val_loss: 3.2546 - val_accuracy: 0.5015

# %%
import matplotlib.pyplot as plt


train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# # min/max 進行標準化至 -1 ~ 1 間

# %%
import matplotlib.pyplot as plt


train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# 將區間變成-1~1之間讓train acc更快上升，但沒有讓test acc變好。

# %% [markdown]
# # 將 mlp 疊更深 (e.g 5~10 層)

# %%
import matplotlib.pyplot as plt


train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# # with GPU

# %%
import matplotlib.pyplot as plt


train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# 沒有明顯的速度差
